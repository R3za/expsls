# %%
from haven import haven_jupyter as hj
from haven import haven_results as hr
from haven import haven_utils as hu
import pprint
import numpy as np

# path to where the experiments are saved
savedir_base = './newres'
exp_config_fname = './exp_configs.py'

# %%
def form_exp_list(exp_groups, exp_config_fname):
    exp_list = []
    for e in exp_groups:
        exp_list += hu.load_py(exp_config_fname).EXP_GROUPS[e]
    return exp_list


# print(form_exp_list(["exp_mushrooms", "exp_ijcnn","exp_rcv1"],exp_config_fname))


markersize = 8
markevery = 15
linewidth = 1
marker = '*'
styles = {}

styles['EXP_SGD_CNST'] = {'label':'K-CNST',  'color':'blue','marker':marker ,
                         'markersize':15, 'marker':'*',
                           'linewidth': 2,
                     'markevery':markevery }

styles['EXP_SGD_DECR'] = {'label':'K-EXP',  'color':'cyan','marker':marker ,
                         'markersize':15, 'marker':'d',
                           'linewidth': 2,
                     'markevery':markevery }


styles['EXP_ACC_SGD_CNST'] = {'label':'ACC-K-CNST',  'color':'orange','marker':marker ,
                         'markersize':15, 'marker':'x',
                           'linewidth': 2,
                     'markevery':markevery }

styles['EXP_ACC_SGD_DECR'] = {'label':'ACC-K-EXP',  'color':'red','marker':marker ,
                         'markersize':15, 'marker':'o',
                           'linewidth': 2,
                     'markevery':markevery }

styles['EXP_SLS_DECR'] = {'label':'SLS-EXP',  'color':'green','marker':marker ,
                         'markersize':15, 'marker':'+',
                           'linewidth': 2,
                     'markevery':markevery }

styles['RIT_SGD'] = {'label':'KR-20',  'color':'black','marker':marker ,
                         'markersize':15, 'marker':'s',
                           'linewidth': 2,
                     'markevery':markevery }

# %% [markdown]
# # ExpList for Losses

# %%
datasets = [ "ijcnn", "mushrooms","rcv1"]
exp_groups = []

for dataset in datasets:
    exp_groups.append("exp_" + dataset)
exp_list = form_exp_list(exp_groups, exp_config_fname)

loss_exp_dict={}
combined_filter_dict={}

for loss_func,loss in [("squared_loss","squared"),("logistic_loss","logistic")]:
    filtered_best_exp_list=[]
    for dataset in datasets:
        for run in range(5):
            rho_filter_list = [        
                ({'opt':{'name':'RIT_SGD'},"runs":run,  
                    "loss_func":loss_func, "dataset":dataset})]
#                    {'style':styles["RIT_SGD"]})]
            exp_list_filtered = hr.filter_exp_list(exp_list, filterby_list=rho_filter_list, verbose=0)
            filtered_best_exp_list+=[hr.get_best_exp_dict(exp_list_filtered, savedir_base, 
                                                filterby_list=rho_filter_list,
                                                metric='train_loss', metric_agg='min', 
                                                return_scores=False, verbose=False)]
            for alpha_t in ["CNST","DECR"]:               
                if loss=="squared" and dataset=="mushrooms" and alpha_t=="DECR":
                    continue
                if loss=="logistic" and dataset=="mushrooms" and alpha_t=="DECR":
                    continue
                if loss=="logistic" and dataset=="ijcnn" and alpha_t=="DECR":
                    continue
                rho_filter_list = [        
                    ({'opt':{'name':'EXP_ACC_SGD','alpha_t':alpha_t },"runs":run,  
                        "loss_func":loss_func, "dataset":dataset})]
#                        {'style':styles["Exp_ACC_SGD_"+alpha_t]})]

                exp_list_filtered = hr.filter_exp_list(exp_list, filterby_list=rho_filter_list, verbose=0)
                filtered_best_exp_list+=[hr.get_best_exp_dict(exp_list_filtered, savedir_base, 
                                                filterby_list=rho_filter_list,
                                                metric='train_loss', metric_agg='min', 
                                                return_scores=False, verbose=False)]

    rfilteres=[({'opt':{'name':'EXP_SGD'},"loss_func":loss_func})] 
    rest_exp=hr.filter_exp_list(exp_list, filterby_list=rfilteres, verbose=0)
    # print(len(rest_exp))        
    filtered_best_exp_list+=rest_exp

    loss_exp_dict[loss_func]=filtered_best_exp_list 

#Adding exceptions:  
rho_filter_list = [        
                     ({'opt':{'name':'EXP_ACC_SGD','alpha_t':"DECR","rho":1000},  
                         "loss_func":"squared_loss", "dataset":"mushrooms"})]
loss_exp_dict["squared_loss"]+=hr.filter_exp_list(exp_list, filterby_list=rho_filter_list, verbose=0)

rho_filter_list = [        
                     ({'opt':{'name':'EXP_ACC_SGD','alpha_t':"DECR","rho":100},  
                         "loss_func":"logistic_loss", "dataset":"mushrooms"})]
loss_exp_dict["logistic_loss"]+=hr.filter_exp_list(exp_list, filterby_list=rho_filter_list, verbose=0)
rho_filter_list = [        
                     ({'opt':{'name':'EXP_ACC_SGD','alpha_t':"DECR","rho":100},  
                         "loss_func":"logistic_loss", "dataset":"ijcnn"})]
loss_exp_dict["logistic_loss"]+=hr.filter_exp_list(exp_list, filterby_list=rho_filter_list, verbose=0)

    
    
print(len(loss_exp_dict["logistic_loss"])   )

for loss_func,loss in [("squared_loss","squared"),("logistic_loss","logistic")]:
    filtered_best_exp_list=[]
    for dataset in datasets:
            filtered_best_exp_list += [        
                ({'opt':{'name':'RIT_SGD'},  
                    "loss_func":loss_func, "dataset":dataset},
                    {'style':styles["RIT_SGD"]})]
            
            for alpha_t in ["CNST","DECR"]: 
                
                filtered_best_exp_list += [        
                    ({'opt':{'name':'EXP_ACC_SGD','alpha_t':alpha_t}, 
                        "loss_func":loss_func, "dataset":dataset},
                       {'style':styles["EXP_ACC_SGD_"+alpha_t]})]
                
                
                
                filtered_best_exp_list += [        
                    ({'opt':{'name':'EXP_SGD','alpha_t':alpha_t, "is_sls":False },  
                        "loss_func":loss_func, "dataset":dataset},
                       {'style':styles["EXP_SGD_"+alpha_t]})]
            
            filtered_best_exp_list +=[        
                    ({'opt':{'name':'EXP_SGD',"is_sls":True },  
                        "loss_func":loss_func, "dataset":dataset},
                       {'style':styles["EXP_SLS_DECR"]})]
             
   
    combined_filter_dict[loss_func]=filtered_best_exp_list 
# print(combined_filter_dict["squared_loss"])
# print(loss_exp_dict["squared_loss"])
print(len(hr.filter_exp_list(loss_exp_dict["logistic_loss"], filterby_list=combined_filter_dict["logistic_loss"], verbose=0)  )  )
# Out:
# 90
# 90

# %% [markdown]
# # Squared Loss

# %%
show_legend_all=None
rm = hr.ResultManager(
                    exp_list= loss_exp_dict["squared_loss"],
                    savedir_base=savedir_base,
                    filterby_list=combined_filter_dict["squared_loss"],
                    verbose= 0       
                     )
rm.get_plot_all(
    avg_across='runs',
    plot_median=True,
    order='metrics_by_groups',
    show_legend_all=show_legend_all,
    legend_last_row_only=True,
    y_metric_list =  ['grad_norm'], 
    x_metric='itr',
    legend_list=['opt.name'], 
    title_list = ['dataset'], 
    groupby_list = ['dataset', 'model'],
    log_metric_list = ["grad_norm"],
    legend_fontsize=16,
     x_fontsize=16,
     y_fontsize=16,
     xtick_fontsize=16,
     ytick_fontsize=16,
     title_fontsize=18,

    map_ylabel_list=[{'train_loss':'Train loss'}, 
                     {'val_acc':'Validation accuracy'},
                     {'grad_norm': 'Gradient Norm'},
                     {'n_grad_evals': 'Number of stochastic gradient evaluations'}],
    map_xlabel_list=[{'itr': '(Gradient evaluations) / 1000'}],
                figsize=(19,5),
    plot_confidence=True,
     legend_kwargs={'bbox_to_anchor':[-.6, -0.25], 
                           'borderaxespad':0., 
                           'ncol':7,'loc':'center'},
    savedir_plots='./squared'
            )
# Out:
# [{'dataset': 'ijcnn', 'loss_func': 'squared_loss', 'opt': {'name': 'RIT_SGD', 'r': 1, 'rho': 100, 'save_dir': 'onmin4'}, 'regularization_factor': 0.01, 'batch_size': 1, 'max_epoch': 10, 'runs': 0}, {'dataset': 'ijcnn', 'loss_func': 'squared_loss', 'opt': {'name': 'EXP_ACC_SGD', 'r': 1, 'alpha_t': 'CNST', 'rho': 1000, 'save_dir': 'onmin3'}, 'regularization_factor': 0.01, 'batch_size': 1, 'max_epoch': 10, 'runs': 0}, {'dataset': 'ijcnn', 'loss_func': 'squared_loss', 'opt': {'name': 'EXP_ACC_SGD', 'r': 1, 'alpha_t': 'DECR', 'rho': 1000, 'save_dir': 'onmin3'}, 'regularization_factor': 0.01, 'batch_size': 1, 'max_epoch': 10, 'runs': 0}, {'dataset': 'ijcnn', 'loss_func': 'squared_loss', 'opt': {'name': 'RIT_SGD', 'r': 1, 'rho': 100, 'save_dir': 'onmin4'}, 'regularization_factor': 0.01, 'batch_size': 1, 'max_epoch': 10, 'runs': 1}, {'dataset': 'ijcnn', 'loss_func': 'squared_loss', 'opt': {'name': 'EXP_ACC_SGD', 'r': 1, 'alpha_t': 'CNST', 'rho': 1000, 'save_dir': 'onmin3'}, 'regularization_factor': 0.01, 'batch_size': 1, 'max_epoch': 10, 'runs': 1}, {'dataset': 'ijcnn', 'loss_func': 'squared_loss', 'opt': {'name': 'EXP_ACC_SGD', 'r': 1, 'alpha_t': 'DECR', 'rho': 1000, 'save_dir': 'onmin3'}, 'regularization_factor': 0.01, 'batch_size': 1, 'max_epoch': 10, 'runs': 1}, {'dataset': 'ijcnn', 'loss_func': 'squared_loss', 'opt': {'name': 'RIT_SGD', 'r': 1, 'rho': 100, 'save_dir': 'onmin4'}, 'regularization_factor': 0.01, 'batch_size': 1, 'max_epoch': 10, 'runs': 2}, {'dataset': 'ijcnn', 'loss_func': 'squared_loss', 'opt': {'name': 'EXP_ACC_SGD', 'r': 1, 'alpha_t': 'CNST', 'rho': 1000, 'save_dir': 'onmin3'}, 'regularization_factor': 0.01, 'batch_size': 1, 'max_epoch': 10, 'runs': 2}, {'dataset': 'ijcnn', 'loss_func': 'squared_loss', 'opt': {'name': 'EXP_ACC_SGD', 'r': 1, 'alpha_t': 'DECR', 'rho': 1000, 'save_dir': 'onmin3'}, 'regularization_factor': 0.01, 'batch_size': 1, 'max_epoch': 10, 'runs': 2}, {'dataset': 'ijcnn', 'loss_func': 'squared_loss', 'opt': {'name': 'RIT_SGD', 'r': 1, 'rho': 100, 'save_dir': 'onmin4'}, 'regularization_factor': 0.01, 'batch_size': 1, 'max_epoch': 10, 'runs': 3}, {'dataset': 'ijcnn', 'loss_func': 'squared_loss', 'opt': {'name': 'EXP_ACC_SGD', 'r': 1, 'alpha_t': 'CNST', 'rho': 1000, 'save_dir': 'onmin3'}, 'regularization_factor': 0.01, 'batch_size': 1, 'max_epoch': 10, 'runs': 3}, {'dataset': 'ijcnn', 'loss_func': 'squared_loss', 'opt': {'name': 'EXP_ACC_SGD', 'r': 1, 'alpha_t': 'DECR', 'rho': 1000, 'save_dir': 'onmin3'}, 'regularization_factor': 0.01, 'batch_size': 1, 'max_epoch': 10, 'runs': 3}, {'dataset': 'ijcnn', 'loss_func': 'squared_loss', 'opt': {'name': 'RIT_SGD', 'r': 1, 'rho': 100, 'save_dir': 'onmin4'}, 'regularization_factor': 0.01, 'batch_size': 1, 'max_epoch': 10, 'runs': 4}, {'dataset': 'ijcnn', 'loss_func': 'squared_loss', 'opt': {'name': 'EXP_ACC_SGD', 'r': 1, 'alpha_t': 'CNST', 'rho': 1000, 'save_dir': 'onmin3'}, 'regularization_factor': 0.01, 'batch_size': 1, 'max_epoch': 10, 'runs': 4}, {'dataset': 'ijcnn', 'loss_func': 'squared_loss', 'opt': {'name': 'EXP_ACC_SGD', 'r': 1, 'alpha_t': 'DECR', 'rho': 1000, 'save_dir': 'onmin3'}, 'regularization_factor': 0.01, 'batch_size': 1, 'max_epoch': 10, 'runs': 4}, {'dataset': 'mushrooms', 'loss_func': 'squared_loss', 'opt': {'name': 'RIT_SGD', 'r': 1, 'rho': 1000, 'save_dir': 'onmin4'}, 'regularization_factor': 0.01, 'batch_size': 1, 'max_epoch': 10, 'runs': 0}, {'dataset': 'mushrooms', 'loss_func': 'squared_loss', 'opt': {'name': 'EXP_ACC_SGD', 'r': 1, 'alpha_t': 'CNST', 'rho': 1000, 'save_dir': 'onmin3'}, 'regularization_factor': 0.01, 'batch_size': 1, 'max_epoch': 10, 'runs': 0}, {'dataset': 'mushrooms', 'loss_func': 'squared_loss', 'opt': {'name': 'RIT_SGD', 'r': 1, 'rho': 1000, 'save_dir': 'onmin4'}, 'regularization_factor': 0.01, 'batch_size': 1, 'max_epoch': 10, 'runs': 1}, {'dataset': 'mushrooms', 'loss_func': 'squared_loss', 'opt': {'name': 'EXP_ACC_SGD', 'r': 1, 'alpha_t': 'CNST', 'rho': 1000, 'save_dir': 'onmin3'}, 'regularization_factor': 0. ...
# /home/exprmnt/repo/svrg/haven/haven_results/__init__.py:1632: UserWarning: Tight layout not applied. tight_layout cannot make axes width small enough to accommodate all axes decorations
#   plt.tight_layout()
# /home/exprmnt/repo/svrg/haven/haven_results/__init__.py:280: UserWarning: Tight layout not applied. tight_layout cannot make axes width small enough to accommodate all axes decorations
#   plt.tight_layout()
# [<Figure size 1368x360 with 3 Axes>]

# %% [markdown]
# # Logistic Loss

# %%
show_legend_all=None
rm = hr.ResultManager(
                    exp_list= loss_exp_dict["logistic_loss"],
                    savedir_base=savedir_base,
                    filterby_list=combined_filter_dict["logistic_loss"],
                    verbose= 0       
                     )


rm.get_plot_all(
    avg_across='runs',
    plot_median=True,
    order='metrics_by_groups',
    show_legend_all=show_legend_all,
    legend_last_row_only=True,
    y_metric_list =  ['grad_norm'], 
    x_metric='itr',
    legend_list=['opt.name'], 
    title_list = ['dataset'], 
    groupby_list = ['dataset', 'model'],
    log_metric_list = ["grad_norm"],
    legend_fontsize=16,
     x_fontsize=16,
     y_fontsize=16,
     xtick_fontsize=16,
     ytick_fontsize=16,
     title_fontsize=18,

    map_ylabel_list=[{'train_loss':'Train loss'}, 
                     {'val_acc':'Validation accuracy'},
                     {'grad_norm': 'Gradient Norm'},
                     {'n_grad_evals': 'Number of stochastic gradient evaluations'}],
    map_xlabel_list=[{'itr': '(Gradient evaluations) / 1000'}],
                figsize=(19,5),
    plot_confidence=True,
     legend_kwargs={'bbox_to_anchor':[-.6, -0.26], 'ncol':6, 'loc':'center'},
    savedir_plots='./logistic'
            )
# Out:
# [{'dataset': 'ijcnn', 'loss_func': 'logistic_loss', 'opt': {'name': 'RIT_SGD', 'r': 1, 'rho': 100, 'save_dir': 'onmin4'}, 'regularization_factor': 0.01, 'batch_size': 1, 'max_epoch': 10, 'runs': 0}, {'dataset': 'ijcnn', 'loss_func': 'logistic_loss', 'opt': {'name': 'EXP_ACC_SGD', 'r': 1, 'alpha_t': 'CNST', 'rho': 1000, 'save_dir': 'onmin3'}, 'regularization_factor': 0.01, 'batch_size': 1, 'max_epoch': 10, 'runs': 0}, {'dataset': 'ijcnn', 'loss_func': 'logistic_loss', 'opt': {'name': 'RIT_SGD', 'r': 1, 'rho': 100, 'save_dir': 'onmin4'}, 'regularization_factor': 0.01, 'batch_size': 1, 'max_epoch': 10, 'runs': 1}, {'dataset': 'ijcnn', 'loss_func': 'logistic_loss', 'opt': {'name': 'EXP_ACC_SGD', 'r': 1, 'alpha_t': 'CNST', 'rho': 1000, 'save_dir': 'onmin3'}, 'regularization_factor': 0.01, 'batch_size': 1, 'max_epoch': 10, 'runs': 1}, {'dataset': 'ijcnn', 'loss_func': 'logistic_loss', 'opt': {'name': 'RIT_SGD', 'r': 1, 'rho': 100, 'save_dir': 'onmin4'}, 'regularization_factor': 0.01, 'batch_size': 1, 'max_epoch': 10, 'runs': 2}, {'dataset': 'ijcnn', 'loss_func': 'logistic_loss', 'opt': {'name': 'EXP_ACC_SGD', 'r': 1, 'alpha_t': 'CNST', 'rho': 1000, 'save_dir': 'onmin3'}, 'regularization_factor': 0.01, 'batch_size': 1, 'max_epoch': 10, 'runs': 2}, {'dataset': 'ijcnn', 'loss_func': 'logistic_loss', 'opt': {'name': 'RIT_SGD', 'r': 1, 'rho': 100, 'save_dir': 'onmin4'}, 'regularization_factor': 0.01, 'batch_size': 1, 'max_epoch': 10, 'runs': 3}, {'dataset': 'ijcnn', 'loss_func': 'logistic_loss', 'opt': {'name': 'EXP_ACC_SGD', 'r': 1, 'alpha_t': 'CNST', 'rho': 1000, 'save_dir': 'onmin3'}, 'regularization_factor': 0.01, 'batch_size': 1, 'max_epoch': 10, 'runs': 3}, {'dataset': 'ijcnn', 'loss_func': 'logistic_loss', 'opt': {'name': 'RIT_SGD', 'r': 1, 'rho': 100, 'save_dir': 'onmin4'}, 'regularization_factor': 0.01, 'batch_size': 1, 'max_epoch': 10, 'runs': 4}, {'dataset': 'ijcnn', 'loss_func': 'logistic_loss', 'opt': {'name': 'EXP_ACC_SGD', 'r': 1, 'alpha_t': 'CNST', 'rho': 1000, 'save_dir': 'onmin3'}, 'regularization_factor': 0.01, 'batch_size': 1, 'max_epoch': 10, 'runs': 4}, {'dataset': 'mushrooms', 'loss_func': 'logistic_loss', 'opt': {'name': 'RIT_SGD', 'r': 1, 'rho': 100, 'save_dir': 'onmin4'}, 'regularization_factor': 0.01, 'batch_size': 1, 'max_epoch': 10, 'runs': 0}, {'dataset': 'mushrooms', 'loss_func': 'logistic_loss', 'opt': {'name': 'EXP_ACC_SGD', 'r': 1, 'alpha_t': 'CNST', 'rho': 1000, 'save_dir': 'onmin3'}, 'regularization_factor': 0.01, 'batch_size': 1, 'max_epoch': 10, 'runs': 0}, {'dataset': 'mushrooms', 'loss_func': 'logistic_loss', 'opt': {'name': 'RIT_SGD', 'r': 1, 'rho': 100, 'save_dir': 'onmin4'}, 'regularization_factor': 0.01, 'batch_size': 1, 'max_epoch': 10, 'runs': 1}, {'dataset': 'mushrooms', 'loss_func': 'logistic_loss', 'opt': {'name': 'EXP_ACC_SGD', 'r': 1, 'alpha_t': 'CNST', 'rho': 1000, 'save_dir': 'onmin3'}, 'regularization_factor': 0.01, 'batch_size': 1, 'max_epoch': 10, 'runs': 1}, {'dataset': 'mushrooms', 'loss_func': 'logistic_loss', 'opt': {'name': 'RIT_SGD', 'r': 1, 'rho': 100, 'save_dir': 'onmin4'}, 'regularization_factor': 0.01, 'batch_size': 1, 'max_epoch': 10, 'runs': 2}, {'dataset': 'mushrooms', 'loss_func': 'logistic_loss', 'opt': {'name': 'EXP_ACC_SGD', 'r': 1, 'alpha_t': 'CNST', 'rho': 1000, 'save_dir': 'onmin3'}, 'regularization_factor': 0.01, 'batch_size': 1, 'max_epoch': 10, 'runs': 2}, {'dataset': 'mushrooms', 'loss_func': 'logistic_loss', 'opt': {'name': 'RIT_SGD', 'r': 1, 'rho': 100, 'save_dir': 'onmin4'}, 'regularization_factor': 0.01, 'batch_size': 1, 'max_epoch': 10, 'runs': 3}, {'dataset': 'mushrooms', 'loss_func': 'logistic_loss', 'opt': {'name': 'EXP_ACC_SGD', 'r': 1, 'alpha_t': 'CNST', 'rho': 1000, 'save_dir': 'onmin3'}, 'regularization_factor': 0.01, 'batch_size': 1, 'max_epoch': 10, 'runs': 3}, {'dataset': 'mushrooms', 'loss_func': 'logistic_loss', 'opt': {'name': 'RIT_SGD', 'r': 1, 'rho': 100, 'save_dir': 'onmin4'}, 'regularization_factor': 0.01, 'batch_size': 1, 'max_epoch': 1 ...
# /home/exprmnt/repo/svrg/haven/haven_results/__init__.py:1632: UserWarning: Tight layout not applied. tight_layout cannot make axes width small enough to accommodate all axes decorations
#   plt.tight_layout()
# /home/exprmnt/repo/svrg/haven/haven_results/__init__.py:280: UserWarning: Tight layout not applied. tight_layout cannot make axes width small enough to accommodate all axes decorations
#   plt.tight_layout()
# [<Figure size 1368x360 with 3 Axes>]
